# %% [markdown]
# # Introduction to python and Core language Concepts

# %% [markdown]
# ## Variables
# ##### To store something in a programming language

# %%
a= 12

# %%
print(a)
# Out:
# 12

# %%
print(12)
# Out:
# 12

# %% [markdown]
# #### comments and multiline comments

# %% [markdown]
# #### comments starts with a hash or triple quote eg.
#
# """
# this is a multiline comments
# like this one
# this is a multiline comments
# like this one this is a multiline comments
# like this one
# this is a multiline comments
# like this one
# print(a)
# """

# %% [markdown]
# ### variables

# %%
a= 12
print(type(a))
# Out:
# <class 'int'>

# %%
b= 12.12
print(type(b))
# Out:
# <class 'float'>

# %%
c= "alfred12.12"
print(type(c))
# Out:
# <class 'str'>

# %% [markdown]
# ### Naming convention

# %% [markdown]
# - variables names can only contain letters, digits and underscore(_)
# - it should not start with a digit
# - variables names are case sensitive Hello, HELLO, hello are not the same
# - avoid using python key works

# %% [markdown]
# ### flow of python
# - execution happens from top to bottom and right to left
# - In case of parenthesis from inner brackets to outer brackets

# %%
mentor_name = "Alfred"
print(mentor_name)
value_1 = 100
print(500)
value_2 = 200
print(value_1)
# Out:
# Alfred
# 500
# 100

# %%
is_visible  = False
is_visible  = True
print(is_visible)
print(type(is_visible))
# Out:
# True
# <class 'bool'>

# %%
a= 12
print(a)
print(type(a))
print(float(a))
print(type(float(a)))
# Out:
# 12
# <class 'int'>
# 12.0
# <class 'float'>

# %%
a= False
print(a)
print(type(a))
print(float(a))
print(type(float(a)))
# Out:
# False
# <class 'bool'>
# 0.0
# <class 'float'>

# %% [markdown]
# ### Operators  1
# - special symbols like -,+,/,*
# operators are used to perform operations on value and variables
# #### types of operators
# ###### - Arithmetic operators (-,+,/,*,//,%)
# ###### - Relational operators (<,>,<=,=>,==)
# ###### - assignment operators (=,+=,-=,*=,*=)
# ###### - logical operators (AND, OR, NOT)
# ###### - Bitwise Operators (&, /,<<,>>,~)

# %%
a= 2
b= 3
c= a + b
print(c)
# Out:
# 5

# %%
a+b
# Out:
# 5

# %%
2* "data science "
# Out:
# 'data science data science '

# %%
### modulos operator (reminder operator)
10 % 3
# Out:
# 1

# %% [markdown]
# #### string properties
