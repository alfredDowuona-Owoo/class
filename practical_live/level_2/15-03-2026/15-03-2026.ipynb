# %% [markdown]
# # Database III

# %% [markdown]
# - Topics Done
#
# ### Common contraints
# ### 1. Aggregations
# ### 2. Nested Queries
# ### 3. Group by
# ### 4. flow of query
#   - from - > where -> group by -> having -> select -> order by --> limit
# ### 5. joins

# %%
# !pip install python-dotenv psycopg2
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting psycopg2
#   Downloading psycopg2-2.9.11-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading psycopg2-2.9.11-cp313-cp313-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 30.3 MB/s  0:00:00
# Installing collected packages: python-dotenv, psycopg2
#
#    ---------------------------------------- 0/2 [python-dotenv]
#    -------------------- ------------------- 1/2 [psycopg2]
#    ---------------------------------------- 2/2 [psycopg2]
#
# Successfully installed psycopg2-2.9.11 python-dotenv-1.2.2
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\Alfred\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
# %pip install python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\Alfred\Desktop\Data Science Learning\Ultimate Data Science & GenAI,Agentic AI Bootcamp\Class\practical_live\level_2\.venv\Scripts\python.exe: No module named pip

# %%
import os
from dotenv import load_dotenv
import psycopg2

# Load the variables
load_dotenv()

try:
    # Connect using variables from .env
    conn = psycopg2.connect(
        host=os.getenv("DB_HOST"),
        database=os.getenv("DB_NAME"),
        user=os.getenv("DB_USER"),
        password=os.getenv("DB_PASS")
    )
    print("Connection successful!")
    #conn.close()
except Exception as e:
    print(f"Error: {e}")
# Out:
# Connection successful!

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM student;")
result = cursor.fetchall()
print(result)
# Out:
# [(1, datetime.datetime(2026, 3, 15, 6, 29, 36, 38435, tzinfo=datetime.timezone.utc), 'Alfred', 30, 'Accra', 12), (2, datetime.datetime(2026, 3, 15, 6, 31, 11, 374391, tzinfo=datetime.timezone.utc), 'Nii Nortey', 25, 'Lagos', 10)]

# %%
for r in result:
    print(r)
# Out:
# (1, datetime.datetime(2026, 3, 15, 6, 29, 36, 38435, tzinfo=datetime.timezone.utc), 'Alfred', 30, 'Accra', 12)
# (2, datetime.datetime(2026, 3, 15, 6, 31, 11, 374391, tzinfo=datetime.timezone.utc), 'Nii Nortey', 25, 'Lagos', 10)

# %%
student_val = ("Pragati", 20, "Delhi", 9)
cursor.execute('''
    INSERT INTO student (name, age, city, class)
    VALUES (%s,%s,%s,%s)
    ''', student_val)

# %%
conn.commit()

# %%
cursor.execute("SELECT * FROM student;")
result = cursor.fetchall()
print(result)
# Out:
# [(1, datetime.datetime(2026, 3, 15, 6, 29, 36, 38435, tzinfo=datetime.timezone.utc), 'Alfred', 30, 'Accra', 12), (2, datetime.datetime(2026, 3, 15, 6, 31, 11, 374391, tzinfo=datetime.timezone.utc), 'Nii Nortey', 25, 'Lagos', 10), (3, datetime.datetime(2026, 3, 15, 8, 20, 30, 63783, tzinfo=datetime.timezone.utc), 'Pragati', 20, 'Delhi', 9)]

# %%
for r in result:
    print(r)
# Out:
# (1, datetime.datetime(2026, 3, 15, 6, 29, 36, 38435, tzinfo=datetime.timezone.utc), 'Alfred', 30, 'Accra', 12)
# (2, datetime.datetime(2026, 3, 15, 6, 31, 11, 374391, tzinfo=datetime.timezone.utc), 'Nii Nortey', 25, 'Lagos', 10)
# (3, datetime.datetime(2026, 3, 15, 8, 20, 30, 63783, tzinfo=datetime.timezone.utc), 'Pragati', 20, 'Delhi', 9)
